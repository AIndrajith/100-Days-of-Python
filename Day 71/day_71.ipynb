# %%
# Spam Email Detector

# Understanding spam Detection and NLP
# Preprocessing Text Data
# Training a Machine Learning Model
# Evaluating Model Performance



# Understanding spam Detection and NLP

# Spam detection is a classification problem where an email is labeled as 
# spam, which is represented by the number one, which are unwanted messages, ads, or phishing emails.
# Also there is not spam, which is also called as ham sometimes or represented
# by zero . these are the genuine emails.
