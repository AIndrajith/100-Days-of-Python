# %%
# Data visualizer app

# Reading and Handling CSV/Excel files
# Creating interactive GUI with Tkinter
# Dynamic Data Visualization using Matplotlib
# Error handling for data input


# Reading and Handling CSV/Excel files
#     pip install pandas matplotlib openpyxl
