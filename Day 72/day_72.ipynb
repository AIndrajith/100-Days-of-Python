# %%
# text sentiment analyzer

# Understading sentiment anlysis
# Using Pre-trained NLP Modesls for sentiment Detection
# Building Sentiment Analyzer using TextBlob and VADER
# Adding user input for Real-Time Analysis


# Understading sentiment anlysis

# Sentiment analysis determines the emotional tone behind the text.
# positive is more like the text expresses positive emotions.
# then we have negative where the text expresses negative emotions and we have neutral. The text has no stron emotions.
# Examples:
#   I love this movie. -> positive sentiment
#   this is the worst service ever -> negative sentiment
#   it's an average day -> neutral sentiment
