# %%
# Understanding Image Classification & Neural Networks
# Loading and Preprocessing the MNIST Dataset
# Building  Convolutional Neural Network (CNN) Model
# Training & Evaluating the Model
# Testing with custom Handwritten Digits

# %%
# Understanding Image Classification & Neural Networks

# this Project uses a Convolutional neural network, or CNN, which is a 
# type of deep learning model designed for image classification tasks.
# The model will take an image of handwritten digits, which are from 
# 0 to 9, as input, and predict the digit with high accuracy.

# The data set that we are using here is the mNIST, or Modified
# National Institute of Standards and Technology dataset, which has 
# 60,000 traning images.
# it has 10,000 test images, and they are all 28 by 28 grayscale
# images of handwritten digits.
